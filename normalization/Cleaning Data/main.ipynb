# %%
import json, csv, string, datetime
from dateutil.parser import parse
import pandas as pd
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

# %% [markdown]
# ### Visualizando os dados

# %%
data = pd.read_json('DATASET.json', lines=True)
data.head()
#YYYY-MM-DD
# Out:
#                              data                           geo            id  \
# 0  Sun May 06 20:41:33 +0000 2018  [19.59433331, -155.97172783]  2.379071e+09
# 1  Sun May 06 20:33:41 +0000 2018         [19.56034, -154.9866]  2.929292e+07
# 2  Sun May 06 20:30:04 +0000 2018    [19.0781667, -155.1876667]  8.149151e+17
# 3  Sun May 06 20:09:43 +0000 2018  [20.02027778, -155.66777778]  4.142280e+08
# 4  Sun May 06 19:46:08 +0000 2018             [19.65, -155.994]  2.011251e+07
#
#               nome                                               text
# 0       tiedyehobo  majic sands beach, kona hawaiiawesome tunes by...
# 1    queeraspoetry  Good am! 🤙🌋 @ Center for Spiritual Living in H...
# 2  Hazards_Network  Monday-January-2018::15:14: An earthquake of m...
# 3   NaomiCooper808       #vacay #Ladat @ Waimea, Hawaii County, Hawai
# 4        vioart527       Last sunset in Hawaii . . . until next time,

# %% [markdown]
# ### Algumas informações sobre o dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6023 entries, 0 to 6022
# Data columns (total 5 columns):
# data    6023 non-null object
# geo     6023 non-null object
# id      6023 non-null float64
# nome    6023 non-null object
# text    6023 non-null object
# dtypes: float64(1), object(4)
# memory usage: 235.4+ KB

# %% [markdown]
# ### Campos nulos ?

# %%
data.isnull().sum()
# Out:
# data    0
# geo     0
# id      0
# nome    0
# text    0
# dtype: int64

# %% [markdown]
# ### Formatando datas

# %%
def parse_datetime(value):
    time_tuple = parsedate_tz(value)
    timestamp  = mktime_tz(time_tuple)
    return datetime.datetime.fromtimestamp(timestamp)

times = { "data": [], "time": [], "lat":  [], "long": [] }
for x, k in zip(data['data'].apply(parse), data['geo']):
    time_out = str(x).split(" ")
    geo_out  = k.replace("[","").replace("]","").split(',')
    times["data"].append(time_out[0])
    times["time"].append(str(time_out[1]).replace("+00:00",""))
    times["lat"].append(geo_out[0])
    times["long"].append(geo_out[1])
    
#Atualizações no dataframe
data['data'] = pd.Series(times['data'])
data['time'] = pd.Series(times['time'])
data['lat']  = pd.Series(times['lat'])
data['long'] = pd.Series(times['long'])
data.pop('geo')
data.columns = ['date', 'id_str','user_name','text', 'time', 'latitude', 'longitude']

# %%
data.head()
# Out:
#          date        id_str        user_name  \
# 0  2018-05-06  2.379071e+09       tiedyehobo
# 1  2018-05-06  2.929292e+07    queeraspoetry
# 2  2018-05-06  8.149151e+17  Hazards_Network
# 3  2018-05-06  4.142280e+08   NaomiCooper808
# 4  2018-05-06  2.011251e+07        vioart527
#
#                                                 text      time     latitude  \
# 0  majic sands beach, kona hawaiiawesome tunes by...  20:41:33  19.59433331
# 1  Good am! 🤙🌋 @ Center for Spiritual Living in H...  20:33:41     19.56034
# 2  Monday-January-2018::15:14: An earthquake of m...  20:30:04   19.0781667
# 3       #vacay #Ladat @ Waimea, Hawaii County, Hawai  20:09:43  20.02027778
# 4       Last sunset in Hawaii . . . until next time,  19:46:08        19.65
#
#         longitude
# 0   -155.97172783
# 1       -154.9866
# 2    -155.1876667
# 3   -155.66777778
# 4        -155.994

# %% [markdown]
# ### Filtros de Limpeza

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

def remove_dots(text):
    return  re.compile(
        f'[{re.escape(string.punctuation)}]'
    ).sub(' ', text)

def remove_stopwords(text):
    stemmer = SnowballStemmer("english")
    make   = TweetTokenizer()
    tokens = make.tokenize( remove_dots( remove_numbers(text) ) )
    return [w.lower() for w in tokens if not w in set(stopwords.words('english'))]

# %%
for k, x in enumerate(data['text']):
    data.loc[k,'text'] = str(" ".join(remove_stopwords(x)))

# %% [markdown]
# # Removendo conteúdo duplicado

# %%
#mostando perfis de spam
#similaridade dos spams/bots ...  
#Mesmo horário, mesmo conteúdo da msg, mesma lat e long
spams = data[data['text'].duplicated(keep = False)]
spams
# Out:
#             date        id_str        user_name  \
# 0     2018-05-06  2.379071e+09       tiedyehobo
# 1     2018-05-06  2.929292e+07    queeraspoetry
# 2     2018-05-06  8.149151e+17  Hazards_Network
# 3     2018-05-06  4.142280e+08   NaomiCooper808
# 4     2018-05-06  2.011251e+07        vioart527
# 5     2018-05-06  2.379071e+09       tiedyehobo
# 6     2018-05-06  1.864570e+07          syvideo
# 7     2018-05-06  1.882971e+07         rodney_o
# 8     2018-05-06  4.934616e+08       ashleyyyz3
# 9     2018-05-06  1.714726e+09        itsnotben
# 10    2018-05-06  2.918153e+09        eq_map_es
# 11    2018-05-06  8.195031e+08        eq_map_ww
# 12    2018-05-06  2.955319e+08           eq_map
# 13    2018-05-06  6.063745e+08    shellokitty78
# 14    2018-05-06  8.149151e+17  Hazards_Network
# 15    2018-05-06  3.583507e+07      chazatronic
# 16    2018-05-06  8.149151e+17  Hazards_Network
# 17    2018-05-06  8.149151e+17  Hazards_Network
# 18    2018-05-06  4.228522e+09      DepremDunya
# 19    2018-05-06  2.918153e+09        eq_map_es
# 20    2018-05-06  8.195031e+08        eq_map_ww
# 21    2018-05-06  2.955319e+08           eq_map
# 22    2018-05-06  4.142280e+08   NaomiCooper808
# 23    2018-05-06  4.228522e+09      DepremDunya
# 24    2018-05-06  2.918153e+09        eq_map_es
# 25    2018-05-06  8.195031e+08        eq_map_ww
# 26    2018-05-06  2.955319e+08           eq_map
# 27    2018-05-06  1.534662e+07     TrevorHughes
# 28    2018-05-06  3.620020e+08         jaynedmc
# 29    2018-05-06  2.585930e+07          sdbrady
# ...          ...           ...              ...
# 5829  2018-05-01  5.695078e+07      selphie6999
# 5843  2018-04-30  5.695078e+07      selphie6999
# 5847  2018-04-30  1.855154e+09          etk_143
# 5849  2018-04-30  5.695078e+07      selphie6999
# 5854  2018-04-30  2.379071e+09       tiedyehobo
# 5877  2018-04-30  1.390290e+08           Rabuuf
# 5880  2018-04-30  5.695078e+07      selphie6999
# 27    five homes confirmed destroyed lava flow big i...  04:26:56
# 28    bigislandlove hawaii bigisland maunalani whata...  03:44:32
# 29    free olukai shoes thanks nu skin 😍 😎 👍 🏖 waiko...  03:05:11
# ...                                                 ...       ...
# 5829                               i kaomi pl makawao h  00:05:17
# 5843                              i walgreens kahului h  23:19:09
# 5847                            kahaluu 🌴 kahaluu hawai  22:47:24
# 5849                                i walmart kahului h  22:29:47
# 5854  ganja tiedye apprenticetqlarye tiedyehobo hipp...  21:43:05
# 5877                ain ’ bones kaiser permanente hawai  20:00:35
# 5880                   i apex triangle square kahului h  19:35:03
# 5881      i hawaii state federal credit union kahului h  19:34:31
# 5884  guardian tomatoes dpffgznd hawaii tiedyehobo t...  19:26:59
# 5890  finally getting stupid ankle looked hawaii rad...  19:04:11
# 5897               fun times latepost kailua kona hawai  18:01:38
# 5898                             i コナ国際空港 kailua kona h  18:01:25
# 5900  when i leave hawaii wear work pants meetings m...  17:53:16
# 5904     magnitude earthquake km volcano hi unitedstate  17:05:06
# 5906    magnitude earthquake km volcano hi united state  17:00:08
# 5909  dpffgznd tiedyehobo tiedye hippie hawaii kitty...  15:40:49
# 5912    magnitude earthquake km volcano hi united state  14:55:04
# 5917              second last sunset kona keauhou hawai  12:31:22
# 5937      magnitude earthquake km pāhala hi unitedstate  07:05:04
# 5938      magnitude earthquake km pāhala hi unitedstate  06:55:04
# 5967      magnitude earthquake km pāhala hi unitedstate  02:35:04
# 5972  want work four seasons resorts lana we hiring ...  01:52:14
# 5975  day dinosaurs octopus big ass whale bishopmuse...  01:23:31
# 5990    magnitude earthquake km volcano hi united state  23:45:05
# 5994  magnitude earthquake km fern acres hi unitedstate  23:25:05
# 5997                    pieces big island hawaii island  23:23:18
# 6002  brunch date spam 🐽 ahi tuna 🐟 food hawaii yum ...  23:06:48
# 6003     magnitude earthquake km volcano hi unitedstate  23:05:05
# 6006  good effort mana boy tomasellikeiki hilosparta...  22:37:56
# 6008                                  yum honokaa hawai  22:14:51
#
#          latitude       longitude
# 0     19.59433331   -155.97172783
# 1        19.56034       -154.9866
# 2      19.0781667    -155.1876667
# 3     20.02027778   -155.66777778
# 4           19.65        -155.994
# 5        19.52575      -155.92358
# 6         19.4735         -154.92
# 7       19.204109     -155.479005
# 8         19.4764        -155.923
# 9       19.431649      -155.21687
# 10         19.046        -155.173
# 11         19.046        -155.173
# 12         19.046        -155.173
# 13          19.65        -155.994
# 14     19.3713341    -155.0338287
# 15    19.59433331   -155.97172783
# 16     19.0475006    -155.0298309
# 17        19.4314       -154.8766
# 18          19.52         -155.01
# 19         19.419        -155.212
# 20         19.419        -155.212
# 21         19.419        -155.212
# 22    20.02027778   -155.66777778
# 23          19.43         -155.24
# 24         19.425        -155.223
# 25         19.425        -155.223
# 26         19.425        -155.223
# 27     19.4804455   -154.83270102
# 28    19.94180051   -155.87206692
# 29        19.9431         -155.79
# ...           ...             ...
# 5829  20.83663242   -156.32597431
# 5843  20.88828689   -156.46549344
# 5847      19.5833        -155.969
# 5849  20.87832351   -156.45540345
# 5854     19.52575      -155.92358
# 5877     19.67446      -156.01537
# 5880  20.88746162   -156.45506656
# 5881  20.88770546   -156.45512536
# 5884     19.52575      -155.92358
# 5890     19.64162      -155.99506
# 5897        19.65        -155.994
# 5898  19.73549893   -156.04078617
# 5900  19.73888889   -156.04555556
# 5904       19.391        -155.249
# 5906       19.357        -155.124
# 5909     19.52575      -155.92358
# 5912       19.348        -155.263
# 5917      19.5653        -155.965
# 5937       19.193        -155.468
# 5938       19.196        -155.466
# 5967       19.195        -155.416
# 5972   20.8693387    -156.9061034
# 5975     19.49052     -155.912511
# 5990       19.381        -155.242
# 5994       19.381        -155.087
# 5997  19.56666667          -155.5
# 6002     19.64373      -155.99352
# 6003       19.282          -155.2
# 6006      19.7055        -155.086
# 6008      20.0776        -155.464
#
# [3569 rows x 7 columns]

# %% [markdown]
# ### Removendo perfis de conteúdo duplicado/spam

# %%
#pegando os 'user_name' do perfis spams
for names in set(spams['user_name']):
    print(names)
    #Essa linha exclui todos os perfis com base no indice de cada 'user_name'
    data.drop(data[data['user_name'] == names ].index, inplace = True)

# teste de perfil deletado
#data[data['user_name'].str.match('QuakesToday')]
# Out:
# symbolicimagery
# mikeygomikey
# USGSBigQuakes
# Hazards_Network
# tiedyehobo
# eq_map_ww
# USGSted
# jjkusowski
# THEREALPUNK
# iM0Nica
# FindingBeauty_M
# tmj_mau_hrta
# NaomiCooper808
# miu_north
# TiffanyMCarlson
# JchanKchan
# fafjrock
# arielkcurry
# WordsOfVikram
# Verticalviking
# thesnorkelstore
# tmj_HI_cstsrv
# ekgeee
# KonaHomeTeam
# NewEarthquake
# radxnickelx
# SoCalRestaurant
# AAgbayani
# FourSeasonsJobs
# tmj_mau_cosmo
# RobertPerryHI
# eq_map
# espejomx
# LastQuake
# ProjectVisionHI
# BeckBBeck
# DuckSoSoft
# GeorgeIzvernari
# Dieuwkevdpol
# MrTrevorJames
# AngelaConners_
# glemaud
# WanderTheMap
# NotableBirdsHI
# Superfly8o8
# DepremDunya
# Quake_Tracker4
# hexdxche
# ashleypbaby
# Electric_Surfer
# tmj_hi_retail
# Rabuuf
# shellokitty78
# u_nagi2356
# Chase_Schnur
# sannebuurma
# ynoelani
# LahainaGallery
# DougTho89360871
# pintsizegourmet
# OptimisticVibe1
# earthquakeBot
# konafriends
# earthshook
# sunflwer1975
# mike_herron
# tmj_mau_retail
# jammaquino
# Sixseat
# welshietouring
# evee
# Indica_Honey
# etk_143
# sdbrady
# vioart527
# paparacchi
# ShortiniPhotog
# MichaelVergona
# DeVante1
# iamcamjones
# eq_map_es2
# syvideo
# queeraspoetry
# therealmrsHDUB
# chowbabylovin
# educaciondecr
# AlxKawakami
# qball13z
# JakeLlaguno
# NeerajPeriwal
# patogawa
# CaraMel_HI
# autoRNG
# clarklittle
# Joechris1988
# Astro_Herv
# disasteraware
# SkylarPeterson
# paulgotelweb
# rodney_o
# HiloHennaHut
# MarkOwnsUrFace
# loftandlearn
# tmj_hi_nursing
# senseividal
# tmj_HI_skltrd
# AprilLButcher
# hellocamille02
# jaywashradio
# barkingbbq
# tmj_HI_facmgmt
# Urban_Driven
# NightSea_ageha
# LitoArkangel
# alexandrov59
# Travelmonkie
# ashleyyyz3
# angieinpixels
# RasSparrow
# MauiDarci
# megantg
# chrisjb
# KingsShopsHI
# chrisgrohusko
# RamonDelBarrio
# TrevorHughes
# PineappleClan
# Randall_Shirley
# Aceman808
# 5oclockbot
# QuakesToday
# cmartiniyoga
# MaddestMax
# alikaboy4music
# jaynedmc
# henrymortega1
# captainm56
# chazatronic
# DepremTR
# ralphmalani
# tmj_usa_aero
# selphie6999
# paderan
# foodoirs
# lanaiacademy
# Cerrinia
# infogempa
# sstnblcstlns
# MarkNakashima
# vinillaskyz
# _tamikaanne
# JustinRusnak
# satoko0518
# DamienAwai
# eq_map_es
# AnneMurata
# anelajade
# zeketomaselli
# junniiya
# cyulit
# HappyMonkey604
# PattyKWilliams
# tmj_hi_sales
# BigEarthquakes
# Ross22Tyler
# tmj_mau_health
# itsnotben
# OhanaSuh1
# adamglinder
# drummerchris
# object82
# ChiokeMusic
# RobertJohnCook

# %% [markdown]
# ### Removendo perfils de spam manualmente

# %%
#data[data['user_name'].str.contains("tmj_")] #mostra quais perfis tem relação com tmj_  ...
#Foi observado que quase sempre os perfis que propagavam spam, ou msg não relacionadas ao desastre.
data = data[~ data['user_name'].str.contains("tmj")]
data = data[~ data['user_name'].str.contains("eq_map")]
data = data[~ data['user_name'].str.contains("HiloHawaii_")]
data = data[~ data['user_name'].str.contains("5oclockbot")]

# %% [markdown]
# # Encontrando Interesse

# %%
data.head()
# Out:
#             date       id_str      user_name  \
# 1725  2018-05-29  401257758.0  ArcturusFlyer
# 1727  2018-05-29   71276351.0   HI_physician
# 1758  2018-05-28  618294231.0      _grammar_
# 1762  2018-05-28   19560314.0      rockyrooo
# 1771  2018-05-28   19560314.0      rockyrooo
#
#                                                    text      time  \
# 1725                                        south point  01:06:45
# 1727  want work envision we hiring kealakekua hi cli...  01:06:02
# 1758  it drcameronmurray could posted “ time missing...  23:34:00
# 1762  yum yum yum yum yum drinking malolo special pa...  22:58:43
# 1771  never lined red ipa drinking red giant ale big...  22:48:18
#
#          latitude       longitude
# 1725   18.9121422    -155.6819064
# 1727   19.5208333       -155.9225
# 1758  18.21528411   -155.82388267
# 1762      20.0247        -155.662
# 1771      20.0247        -155.662

# %%
words = list(set(remove_stopwords(
    str(open('disasters_words.txt').readlines())
)))
words
# Out:
# ['quaker',
#  'deformation',
#  'razed',
#  'vulcao',
#  'allowance',
#  'fire',
#  'eruptions',
#  'hut',
#  'vulcão',
#  'wasted',
#  'caldera',
#  'aghast',
#  'safe',
#  'condo',
#  'larder',
#  'orison',
#  'lost',
#  'pyroclastic',
#  'jittery',
#  'pali',
#  'pahala',
#  'aid',
#  'volcanowatch',
#  'diasters',
#  'seismograph',
#  'meal',
#  'magma',
#  'lua',
#  'shook',
#  'mess',
#  'leave',
#  'appeal',
#  'subsistence',
#  'magnitude',
#  'sismic',
#  'refuge',
#  'endowment',
#  'danger',
#  'anxious',
#  'shelters',
#  'disturbed',
#  'store',
#  'contribution',
#  'shattered',
#  'ash',
#  'feed',
#  'nervous',
#  'active',
#  'route',
#  'evacuee',
#  'move',
#  'trembler',
#  'tears',
#  'central',
#  'ejecta',
#  'distressed',
#  'safety',
#  'comestible',
#  'phreatomagmatic',
#  'scoria',
#  'vulcanian',
#  'fault',
#  'nourishment',
#  'smashed',
#  'seismism',
#  'uneasy',
#  'surface',
#  'waves',
#  'fahrenheit',
#  'tuff',
#  'fumarole',
#  'clinic',
#  'shock',
#  'vulcanoes',
#  'displace',
#  'foodstuff',
#  'lava',
#  'cloud',
#  'tephra',
#  'pleading',
#  'shelter',
#  'volcano',
#  'sustenance',
#  'shake',
#  'begging',
#  'movement',
#  'monogenetic',
#  'tectonic',
#  'cloudy',
#  'petition',
#  'tectonics',
#  'ration',
#  'aftershocks',
#  'evacuation',
#  'seismicity',
#  'solfatara',
#  'broken',
#  'vents',
#  'repose',
#  'careful',
#  'andesite',
#  'refreshment',
#  'ruined',
#  'coulee',
#  'crater',
#  'scared',
#  'devastated',
#  'flow',
#  'earthquake',
#  'shaky',
#  'nutrition',
#  'temblor',
#  'assistance',
#  'killed',
#  'fallout',
#  'bench',
#  'dacite',
#  'afraid',
#  'abandon',
#  'prayers',
#  'lahar',
#  'remove',
#  'imploring',
#  'crowd',
#  'pumice',
#  'pull',
#  'ravaged',
#  'apprehensive',
#  'aliment',
#  'quake',
#  'fidgety',
#  'asylum',
#  'concerned',
#  'fissures',
#  'cinder',
#  'erupts',
#  'entreaty',
#  'sismo',
#  'bomb',
#  'leilani',
#  'nervy',
#  'destroyed',
#  '🔥',
#  'ashes',
#  'subsidy',
#  'vapor',
#  'restless',
#  'volcanic',
#  'annihilated',
#  'rhyolite',
#  'emission',
#  'vulcan',
#  'forsake',
#  'charity',
#  'conduit',
#  'service',
#  'sanctuary',
#  'apartment',
#  'tilt',
#  'block',
#  'plug',
#  'emergency',
#  'dwelling',
#  'vent',
#  'celsius',
#  'support',
#  'macroseism',
#  'disintegrated',
#  'craving',
#  'withdraw',
#  'donatios',
#  'spooked',
#  'demolished',
#  'instituition',
#  'microseism',
#  'chow',
#  'survive',
#  '🌋',
#  'concerns',
#  'eruption',
#  'seismograms',
#  'seism',
#  'holocene',
#  'surge',
#  'steaming',
#  'quit',
#  'asthenosphere',
#  'relief',
#  'terremoto',
#  'seismology',
#  'cone',
#  'pahoehoe',
#  'basalt',
#  'epicentre',
#  'amplitude',
#  'bail',
#  'uptight',
#  'kipuka',
#  'nutriment',
#  'pele',
#  'lodging',
#  'convulsion',
#  'airfall',
#  'mainshock',
#  'seimicity',
#  'tremor',
#  'erupting',
#  'bigisland',
#  'kilauea',
#  'erupt',
#  'transport',
#  'request',
#  'help',
#  'ashfall',
#  'laze']

# %%
data['text'][3216]
# Out:
# 'these images surreal 🌋 many displaced others'

# %%
#Tamanho médio das palavras em inglês https://arxiv.org/pdf/1208.6109.pdf
#Cria uma dataSerie para ser adicionado ao dataFrame
    
def normalize_text():
    
    data['interest'] = False
    
    for index in data.index:
        text = data['text'][index]
        result = pd.Index(remove_stopwords(text)).intersection(pd.Index(words)) 
        if len(result) != 0:
            data.loc[index, 'interest'] = True
normalize_text()

# %%
data[data['interest'] == True]
# Out:
#             date        id_str        user_name  \
# 2114  2018-05-25  2.164855e+08         CDRP_FSU
# 2145  2018-05-24  1.956031e+07        rockyrooo
# 2185  2018-05-23  3.314297e+07            FOX40
# 2191  2018-05-23  2.427974e+08       erivaldoff
# 2242  2018-05-21  2.861508e+09         Palms311
# 2265  2018-05-20  3.022061e+08       LithiaJobs
# 2268  2018-05-20  1.559525e+07           rolodj
# 2277  2018-05-20  1.058711e+09          E2EJobs
# 2289  2018-05-09  4.316392e+07         GevaNeva
# 2315  2018-05-09  4.945080e+08    garrickpeters
# 2319  2018-05-09  1.747856e+07      LukeEclipse
# 2360  2018-05-09  1.223077e+08       IlhamAbbas
# 2369  2018-05-09  8.001107e+17          MNahidC
# 2391  2018-05-09  1.704005e+09       GeneLamkin
# 2392  2018-05-09  3.585713e+07      johnendriss
# 2448  2018-05-09  1.890593e+07    jondavisphoto
# 2511  2018-05-08  3.529421e+08     athinamaeyor
# 2527  2018-05-08  2.182397e+07       nellielaan
# 2573  2018-05-08  1.169230e+08     YNVUCLOTHING
# 2578  2018-05-08  9.491287e+17        aikudeesh
# 2643  2018-05-08  9.673542e+17   _krishnajindal
# 2653  2018-05-08  3.731835e+08      JordanForth
# 2667  2018-05-08  1.962184e+09    picture_happy
# 2716  2018-05-08  4.597936e+07      DandyLyon74
# 2725  2018-05-08  3.470213e+08      MorganVicJo
# 2744  2018-05-08  1.450164e+07       mattical69
# 2768  2018-05-08  4.648238e+07       ChoyToy915
# 2769  2018-05-08  6.679747e+07          k4silva
# 2773  2018-05-08  7.130907e+08   DeniseLaitinen
# 2805  2018-05-08  5.249826e+07        COGdesign
# ...          ...           ...              ...
# 5001  2018-05-03  1.819537e+07        pagejeter
# 5023  2018-05-03  7.349326e+17    acityexplored
# 5041  2018-05-03  4.533033e+08          STthre3
# 5081  2018-05-02  3.088387e+07            wubbi
# 5097  2018-05-02  5.930784e+08       ChefBellec
# 5110  2018-05-02  2.981468e+07           NateyG
# 5164  2018-05-02  2.356405e+07     Vprincemusic
# 5168  2018-05-02  2.339822e+07      oldfartjeff
# 5342  2018-05-02  4.650582e+08  allkinecrossfit
# 5401  2018-05-02  7.117604e+17   missionmolokai
# 5424  2018-05-02  3.627395e+08      Koondolphia
# 5431  2018-05-01  1.197860e+08         AdamBuzz
# 5495  2018-05-01  2.694922e+07    ChanMacNCheez
# 5081                     earthquake earthquake oh kalan  23:01:30
# 5097     ready lunch service looks like pool going busy  22:14:00
# 5110          hole mother god 🌋 haleakala crater maui h  21:36:06
# 5164  last night under palms ocean waves crashing ch...  18:46:08
# 5168  tips i give people i ’ talked help generate sa...  18:31:18
# 5342                  “ it us live legacy left us leave  05:23:35
# 5401  blessed able help others island one ladies church  01:41:04
# 5424       my last brain cell trying survive finals the  00:40:17
# 5431  riley absolutely loved beach showed fear waves...  23:51:32
# 5495      sunrise crater atop mt haleakalā april hawaii  19:56:09
# 5506                gnarly waves 🤙 🏄 ‍ ♀ ️ 😂 island mau  19:23:30
# 5517  decent day discovery 🍹 🍹 maui hawaii foodie di...  18:51:01
# 5529  broken iphone stressing remember livealoha don...  18:30:28
# 5539  haleakala crater outlook tuesday maalaea maala...  17:59:45
# 5543  haleakala crater tuesday outlook haleakala hal...  17:40:47
# 5548              my mission life merely survive thrive  17:23:53
# 5563  dinner view volcano specific 🌋 maui dinner sunset  16:05:16
# 5686  the first “ fire tree ” year sunset sunset mad...  07:22:02
# 5691  a beautiful maui moon cloudy night hawaii aloh...  06:59:01
# 5708                      lost island still smile cause  06:14:55
# 5735  my phone away home pele other garden lanai cit...  05:10:17
# 5761  peahi jaws sunset waves rolling crashing birds...  04:32:24
# 5769           🌋 haleakala maui haleakala crater maui h  04:14:34
# 5853  every meal include lobster crab stuffed grille...  21:49:14
# 5886  monday mood moving newbeginnings gloomy foggy ...  19:21:12
# 5931  fins ✅ mask snorkel ✅ pink towel ✅ camera gear...  08:27:54
# 6001  some fun waves today skimboarding big beach ma...  23:07:15
#
#          latitude       longitude  interest
# 2114  19.47620833   -154.89601167      True
# 2145       19.634         -155.99      True
# 2185    19.497503      -154.95081      True
# 2191  19.91335475   -155.88807723      True
# 2242        20.89         -156.45      True
# 2265   20.8901116    -156.4614301      True
# 2268  19.63532716   -155.99023643      True
# 2277   19.6399924    -155.9969052      True
# 2289  19.49378056   -155.00968889      True
# 2315  20.66347782   -156.44132085      True
# 2319  19.72155086   -155.09616342      True
# 2360  19.56483906   -155.96510866      True
# 2369   19.8261359    -155.4722325      True
# 2391      19.3542        -154.979      True
# 2392       19.501        -154.953      True
# 2448      20.9949      -156.66634      True
# 2511  20.91191351    -156.2431144      True
# 2527       19.501        -154.953      True
# 2573   20.8907108    -156.4644165      True
# 2578      19.4735         -154.92      True
# 2643     19.64188      -155.99315      True
# 2653        19.65        -155.994      True
# 2667     19.39923        -155.287      True
# 2716      19.4735         -154.92      True
# 2725  19.90911245   -155.89905314      True
# 2744     19.64188      -155.99315      True
# 2768  19.32295283   -155.03289375      True
# 2769      19.6211        -155.042      True
# 2773       19.501        -154.953      True
# 2805      19.4735         -154.92      True
# ...           ...             ...       ...
# 5001      20.7858        -155.997      True
# 5023   21.0008086    -156.6538499      True
# 5041    19.421097     -155.286762      True
# 5081  19.41016006   -154.91383875      True
# 5097     19.82792      -155.99132      True
# 5110   20.7148496     -156.250292      True
# 5164     19.82792      -155.99132      True
# 5168   20.8868816    -156.4774079      True
# 5342     20.90556      -156.48851      True
# 5401  21.09657047   -157.03540845      True
# 5424     19.99806      -155.81602      True
# 5431     19.82792      -155.99132      True
# 5495  20.76951362   -156.24264947      True
# 5506   20.8868816    -156.4774079      True
# 5517  20.84899058   -156.50721138      True
# 5529  20.92141052   -156.69447448      True
# 5539      20.8093        -156.491      True
# 5543      20.9107        -156.376      True
# 5548      20.7591        -156.457      True
# 5563  20.84899058   -156.50721138      True
# 5686      20.7407        -156.328      True
# 5691   20.7287148   -156.45058083      True
# 5708     19.64188      -155.99315      True
# 5735  20.82457163   -156.92007012      True
# 5761      20.9167        -156.283      True
# 5769   20.7148496     -156.250292      True
# 5853      20.8724      -156.67726      True
# 5886   20.7590851    -156.2825515      True
# 5931      20.5983         -156.42      True
# 6001   20.6298218    -156.4438228      True
#
# [137 rows x 8 columns]

# %%
data.sort_values(by = 'user_name')
# Out:
#             date        id_str        user_name  \
# 2406  2018-05-09  2.992176e+08             0wwl
# 5042  2018-05-03  1.291239e+09         1fsmith1
# 5837  2018-04-30  1.209477e+08       1hawaiiboy
# 5281  2018-05-02  1.209477e+08       1hawaiiboy
# 2594  2018-05-08  1.209477e+08       1hawaiiboy
# 2528  2018-05-08  1.534514e+09     24k_purelife
# 3960  2018-05-05  1.534514e+09     24k_purelife
# 5736  2018-05-01  1.599495e+09  2boldlygotravel
# 2579  2018-05-08  2.155222e+07          3dueces
# 5977  2018-04-30  3.891496e+08     3rdGalaxiArt
# 3584  2018-05-06  1.720077e+09         808Plate
# 5683  2018-05-01  4.654663e+08             995x
# 5948  2018-04-30  4.654663e+08             995x
# 5851  2018-04-30  3.343737e+07          AKLMaui
# 2847  2018-05-08  3.343737e+07          AKLMaui
# 2825  2018-05-08  3.343737e+07          AKLMaui
# 3620  2018-05-06  3.343737e+07          AKLMaui
# 3214  2018-05-07  3.343737e+07          AKLMaui
# 5431  2018-05-01  1.197860e+08         AdamBuzz
# 2796  2018-05-08  4.001255e+07      AdrianNBCLA
# 4695  2018-05-04  4.001255e+07      AdrianNBCLA
# 5796  2018-05-01  4.001255e+07      AdrianNBCLA
# 3176  2018-05-07  4.001255e+07      AdrianNBCLA
# 4530  2018-05-04  2.058055e+08     AdventurousZ
# 5944  2018-04-30  2.650744e+09   AhlgrenJoachim
# 3515  2018-05-06  1.575202e+09     AirHawaiiNet
# 4093  2018-05-05  1.947484e+09      AlainaFuata
# 4901  2018-05-03  5.032486e+07       AlexVNolan
# 4544  2018-05-04  5.032486e+07       AlexVNolan
# 4899  2018-05-03  5.032486e+07       AlexVNolan
# ...          ...           ...              ...
# 4850  2018-05-03  1.215502e+09        ubchillin
# 5131  2018-05-02  1.215502e+09        ubchillin
# 4725  2018-05-04  1.215502e+09        ubchillin
# 5413  2018-05-02  1.215502e+09        ubchillin
# 4779  2018-05-03  1.215502e+09        ubchillin
# 5427  2018-05-02  2.227127e+07         usdivers
# 4695   20.6498871    -156.4410553     False
# 5796      20.6575        -156.445     False
# 3176      20.6575        -156.445     False
# 4530      20.8861        -156.675     False
# 5944     20.91312      -156.69244     False
# 3515     19.61838      -155.98554      True
# 4093      19.4735         -154.92      True
# 4901  20.69138479   -156.44388733     False
# 4544  20.98590154   -156.66873096     False
# 4899  20.69138479   -156.44388733     False
# ...           ...             ...       ...
# 4850  19.53468321   -155.93114052     False
# 5131  19.42207074   -155.91077019     False
# 4725     19.39923        -155.287      True
# 5413    19.558525    -155.9647268     False
# 4779  19.06669594   -155.79916776     False
# 5427  20.89861111   -156.43055556     False
# 5893   19.9163848   -155.88579531     False
# 2161  19.73457183   -156.04108185     False
# 2337  20.84899058   -156.50721138     False
# 2325        20.69      -156.43889     False
# 2863    20.097952     -155.871263     False
# 2305      19.3712        -155.205     False
# 2306      19.4735         -154.92     False
# 2307      19.4735         -154.92     False
# 3562     19.64188      -155.99315     False
# 4662      20.9348        -156.679     False
# 2860  19.79240139    -156.0274886     False
# 3263  19.96353052   -155.85473295     False
# 4166  19.82831695   -155.99254681     False
# 5655   20.8810166    -156.4544927     False
# 5520      20.2036        -155.734     False
# 2274    19.707243     -155.081635     False
# 3208  19.56666667          -155.5     False
# 5081  19.41016006   -154.91383875      True
# 2338  20.88526312   -156.46493654     False
# 3847     20.91312      -156.69244     False
# 5329    20.692604     -156.442535     False
# 3272  20.68762675   -156.44313433     False
# 5595     19.39923        -155.287     False
# 4253         19.4          -155.0     False
#
# [1289 rows x 8 columns]

# %%
data.to_csv("out_dataset_no_bots.csv",  index = None)

# %%
data[data['text'].str.contains('🌋')]
# Out:
#             date        id_str        user_name  \
# 2643  2018-05-08  9.673542e+17   _krishnajindal
# 2744  2018-05-08  1.450164e+07       mattical69
# 2768  2018-05-08  4.648238e+07       ChoyToy915
# 3012  2018-05-07  5.856215e+07        talonreid
# 3168  2018-05-07  8.419730e+07      soniafarooq
# 3216  2018-05-07  1.239382e+08  EhikuRademacher
# 3370  2018-05-06  1.931350e+08        lopezJ808
# 3515  2018-05-06  1.575202e+09     AirHawaiiNet
# 3663  2018-05-06  5.856215e+07        talonreid
# 3870  2018-05-05  6.333980e+07  campelloricardo
# 4319  2018-05-04  5.398700e+07       Renan_Luan
# 4354  2018-05-04  2.662817e+08     AlyaShowroom
# 4508  2018-05-04  1.679341e+07           Cimcie
# 4586  2018-05-04  2.844813e+08    HandKhandbags
# 4954  2018-05-03  2.180031e+07   kyle_michael_b
# 5110  2018-05-02  2.981468e+07           NateyG
# 5563  2018-05-01  1.819537e+07        pagejeter
# 5769  2018-05-01  1.646349e+07      DrMickeyWit
#
#                                                    text      time  \
# 2643  😱 🌋 above one biggest active volcanoes hawaii ...  18:02:04
# 2744       for pele ’ sake somebody ’ saved droid 🙁 🤖 🌋  05:38:48
# 2768           🌋 a photo shot good friend dana december  04:25:53
# 3012  private plane yesterday around erupting volcan...  12:25:47
# 3168  thank god kilauea waited us leave exploded 🌋 what  02:54:55
# 3216       these images surreal 🌋 many displaced others  00:15:30
# 3370  i ’ glad family safe big island 🔥 🌋 mother nat...  17:27:02
# 3515  キラウエア火山の噴火 🌋 近隣の方々は大丈夫かな … 大自然と共存してる以上 、 仕方のない...  06:18:52
# 3663  ✔ ️ 🤙 🌋 unreal onceinalifetime kilauea kilauea...  00:08:30
# 3870                 hawaiian times haleakala volcano 🌋  14:15:09
# 4319  visita em fevereiro ao vulcão kilauea havaí en...  22:52:32
# 4354  yesterday ’ adventure see madam pele 🌋 volcano...  22:42:38
# 4508  🌋 stay safe bigisland it ’ hard catch puddleju...  18:33:13
# 4586  with heightened 🌋 volcanic activity the big is...  12:36:22
# 4954  just hanging tūtū pele goddess earth fire 🔥 🌋 ...  06:53:28
# 5110          hole mother god 🌋 haleakala crater maui h  21:36:06
# 5563  dinner view volcano specific 🌋 maui dinner sunset  16:05:16
# 5769           🌋 haleakala maui haleakala crater maui h  04:14:34
#
#          latitude       longitude  interest
# 2643     19.64188      -155.99315      True
# 2744     19.64188      -155.99315      True
# 2768  19.32295283   -155.03289375      True
# 3012  19.66965999   -156.02117059      True
# 3168   19.4205571    -155.2891501      True
# 3216  19.49197568   -155.16487645      True
# 3370  19.56666667          -155.5      True
# 3515     19.61838      -155.98554      True
# 3663  19.66965999   -156.02117059      True
# 3870  20.76951362   -156.24264947      True
# 4319     19.39923        -155.287      True
# 4354     19.61838      -155.98554      True
# 4508  20.98590154   -156.66873096      True
# 4586     19.99806      -155.81602      True
# 4954    19.421097     -155.286762      True
# 5110   20.7148496     -156.250292      True
# 5563  20.84899058   -156.50721138      True
# 5769   20.7148496     -156.250292      True

# %%
data[data['text'].str.contains('🔥')]
# Out:
#             date       id_str       user_name  \
# 3081  2018-05-07   14837934.0    richienorton
# 3149  2018-05-07  140547354.0    LisRomeritox
# 3157  2018-05-07  140547354.0    LisRomeritox
# 3370  2018-05-06  193134984.0       lopezJ808
# 4954  2018-05-03   21800307.0  kyle_michael_b
#
#                                                    text      time  \
# 3081  pray big island 🙏 🔥 🤙 🏾 hawaii volcano volcano...  06:43:29
# 3149  😱 🔥 esta vaina apasiona la naturaleza es uff r...  03:38:13
# 3157  😱 la naturaleza es increíble 😱 😱 😱 🔥 🔥 🔥 ⚫ ️ r...  03:22:41
# 3370  i ’ glad family safe big island 🔥 🌋 mother nat...  17:27:02
# 4954  just hanging tūtū pele goddess earth fire 🔥 🌋 ...  06:53:28
#
#          latitude     longitude  interest
# 3081     19.99806    -155.81602      True
# 3149     19.64188    -155.99315      True
# 3157     19.64188    -155.99315      True
# 3370  19.56666667        -155.5      True
# 4954    19.421097   -155.286762      True

# %%
data[data['text'].str.contains('lava')]
# Out:
#             date        id_str        user_name  \
# 2185  2018-05-23  3.314297e+07            FOX40
# 2191  2018-05-23  2.427974e+08       erivaldoff
# 2268  2018-05-20  1.559525e+07           rolodj
# 2450  2018-05-09  1.638822e+07        auroral24
# 2527  2018-05-08  2.182397e+07       nellielaan
# 2773  2018-05-08  7.130907e+08   DeniseLaitinen
# 3220  2018-05-07  2.375675e+09       ooomarrr18
# 3350  2018-05-06  4.533033e+08          STthre3
# 3466  2018-05-06  6.522427e+07  firebladepilot_
# 3558  2018-05-06  4.948112e+08   MugenIsTheName
# 4073  2018-05-05  2.125744e+08     tri_connelly
# 4345  2018-05-04  1.239382e+08  EhikuRademacher
# 4507  2018-05-04  1.574305e+07        azhiaziam
# 4636  2018-05-04  2.387074e+08   chanelledeanna
# 4861  2018-05-03  1.819537e+07        pagejeter
# 4957  2018-05-03  2.246283e+08     BrianSibbitt
# 5001  2018-05-03  1.819537e+07        pagejeter
# 5931  2018-04-30  4.117261e+08           ZeeWil
#
#                                                    text      time  \
# 2185  man defending hawaii home volcano hit by flami...  14:34:58
# 2191                   i lava lava beach club kamuela h  02:34:30
# 2268  i island lava java bistro amp grill lavajavaha...  22:09:15
# 2450  wine tasting cousintime hawaii travel wesafe l...  02:11:10
# 2527       still far away us hope stops soon pahoa lava  23:03:02
# 2773    here pahoa community center update leilani lava  03:59:03
# 3220  drinking lavaman red ale konabrewingco laniake...  00:01:37
# 3350                    spent time lava tube black sand  18:28:06
# 3466  crazy video lava flow today middle housing are...  09:00:49
# 3558  this lava flow eruption looks like happening r...  04:22:00
# 4073                udon hilo hi earthquakes lava flows  05:14:02
# 4345  growing big island i remember going visit lava...  22:44:33
# 4507  the kilauea lavaflow going leilaniestates stay...  18:48:42
# 4636  exploring caves hana 🦀 🦐 🐠 🐟 🌊 maui hawaii han...  06:30:29
# 4861  black amp blue 🌊 maui hawaii island beach lava...  18:06:44
# 4957  kilauea volcano spitting lava lots action erup...  06:37:18
# 5001  beach lava 🌊 maui blacksandbeach hawaii ocean ...  03:49:10
# 5931  fins ✅ mask snorkel ✅ pink towel ✅ camera gear...  08:27:54
#
#          latitude       longitude  interest
# 2185    19.497503      -154.95081      True
# 2191  19.91335475   -155.88807723      True
# 2268  19.63532716   -155.99023643      True
# 2450  19.44571214   -155.28476932     False
# 2527       19.501        -154.953      True
# 2773       19.501        -154.953      True
# 3220      19.7354        -156.041     False
# 3350      20.7858        -155.997      True
# 3466      19.4735         -154.92      True
# 3558  19.67352918   -155.08122929      True
# 4073      19.7055        -155.086      True
# 4345      19.4139        -155.246      True
# 4507      19.4735         -154.92      True
# 4636     20.78551       -156.0276      True
# 4861     20.78619      -156.00643      True
# 4957     19.61838      -155.98554      True
# 5001      20.7858        -155.997      True
# 5931      20.5983         -156.42      True

# %%
data['text'][2450]
# Out:
# 'wine tasting cousintime hawaii travel wesafe lavaontheotherside'

# %%
'''
#salvar lista de nomes dos usuários
k = open('names.txt','a')
for x in data[data['interest'] == True]['user_name']:
    k.write(str(x)+"\n")
'''
# Out:
# '\n#salvar lista de nomes dos usuários\nk = open(\'names.txt\',\'a\')\nfor x in data[data[\'interest\'] == True][\'user_name\']:\n    k.write(str(x)+"\n")\n'
