# %%
import json, csv, string, re, emoji
import pandas as pd
import numpy  as np
#PNL
from nltk.tokenize import TweetTokenizer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

# %%
data = pd.read_csv('out_dataset.csv')
#data = pd.read_csv('data_set.csv')
data.dropna(inplace = True)

# %%
data.head()
# Out:
#          date        id_str   user_name  \
# 0  2018-05-09  2.992176e+08        0wwl
# 1  2018-05-03  1.291239e+09    1fsmith1
# 2  2018-05-08  1.209477e+08  1hawaiiboy
# 3  2018-04-30  1.209477e+08  1hawaiiboy
# 4  2018-05-02  1.209477e+08  1hawaiiboy
#
#                                                 text      time   latitude  \
# 0                 Island living 🏝🥥🌺 @ Kapalua, Hawai  03:44:09  20.996700
# 1  Blessed to be home in Hawai’i for a few weeks!...  01:25:05  19.634691
# 2  The tools at the ready for afternoon strawberr...  20:13:31  19.723000
# 3                           Spirits @ Sansei Waikolo  23:31:26  19.913838
# 4           Pint and a shot#guinness #tullamoredew @  09:01:52  19.925450
#
#     longitude
# 0 -156.653000
# 1 -155.989839
# 2 -156.005000
# 3 -155.879406
# 4 -155.884330

# %%
#data[data['text'].str.contains('hawaii')]

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

def remove_dots(text):
    return  re.compile(
        f'[{re.escape(string.punctuation)}]'
    ).sub(' ', text)

def remove_stopwords(text):
    make   = TweetTokenizer()
    tokens = make.tokenize( remove_dots( remove_numbers(text) ) )
    return [w.lower() for w in tokens if not w in set(stopwords.words('english'))]

# %%
words = set(remove_stopwords(
    " ".join([x for x in open('disasters_words.txt')])
))

# %%
words
# Out:
# {'abandon',
#  'active',
#  'afraid',
#  'aftershocks',
#  'aghast',
#  'aid',
#  'airfall',
#  'aliment',
#  'allowance',
#  'amplitude',
#  'andesite',
#  'annihilated',
#  'anxious',
#  'apartment',
#  'appeal',
#  'apprehensive',
#  'aqua',
#  'ash',
#  'ashes',
#  'ashfall',
#  'assistance',
#  'asthenosphere',
#  'asylum',
#  'bail',
#  'basalt',
#  'begging',
#  'bench',
#  'bigisland',
#  'block',
#  'bomb',
#  'broken',
#  'caldera',
#  'careful',
#  'celsius',
#  'central',
#  'charity',
#  'chow',
#  'cinder',
#  'clinic',
#  'cloud',
#  'cloudy',
#  'comestible',
#  'concerned',
#  'concerns',
#  'condo',
#  'conduit',
#  'cone',
#  'contribution',
#  'convulsion',
#  'crater',
#  'craving',
#  'crowd',
#  'dacite',
#  'deformation',
#  'demolished',
#  'depth',
#  'destroyed',
#  'devastated',
#  'disintegrated',
#  'displace',
#  'distressed',
#  'disturbed',
#  'donatios',
#  'dwelling',
#  'earthquake',
#  'ejecta',
#  'emergency',
#  'emission',
#  'endowment',
#  'entreaty',
#  'epicentre',
#  'erupt',
#  'erupting',
#  'eruption',
#  'eruptions',
#  'erupts',
#  'evacuation',
#  'evacuee',
#  'fahrenheit',
#  'fallout',
#  'fault',
#  'fearful',
#  'feed',
#  'fidgety',
#  'fissures',
#  'flow',
#  'food',
#  'foodstuff',
#  'forsake',
#  'fumarole',
#  'hawai',
#  'hawaii',
#  'help',
#  'hilo',
#  'holocene',
#  'home',
#  'house',
#  'hut',
#  'imploring',
#  'instituition',
#  'jittery',
#  'jumpy',
#  'keep',
#  'kilauea',
#  'killed',
#  'kona',
#  'lahar',
#  'larder',
#  'lava',
#  'laze',
#  'leave',
#  'leilani',
#  'lodging',
#  'lost',
#  'lua',
#  'macroseism',
#  'magma',
#  'magnitude',
#  'mainshock',
#  'meal',
#  'mess',
#  'microseism',
#  'move',
#  'movement',
#  'nature',
#  'nervous',
#  'nervy',
#  'nourishment',
#  'nutriment',
#  'nutrition',
#  'orison',
#  'pahala',
#  'pahoehoe',
#  'pali',
#  'pele',
#  'petition',
#  'phreatomagmatic',
#  'plate',
#  'pleading',
#  'plug',
#  'prayers',
#  'pull',
#  'pumice',
#  'pyroclastic',
#  'quake',
#  'quaker',
#  'quit',
#  'ration',
#  'ravaged',
#  'razed',
#  'refreshment',
#  'refuge',
#  'relief',
#  'remove',
#  'repose',
#  'request',
#  'restless',
#  'rhyolite',
#  'ruined',
#  'safety',
#  'sanctuary',
#  'scared',
#  'scoria',
#  'seimicity',
#  'seism',
#  'seismicity',
#  'seismism',
#  'seismograms',
#  'seismograph',
#  'seismology',
#  'service',
#  'shake',
#  'shaky',
#  'shattered',
#  'shelter',
#  'shelters',
#  'shock',
#  'shook',
#  'sismo',
#  'smashed',
#  'solfatara',
#  'spooked',
#  'steaming',
#  'store',
#  'subsidy',
#  'subsistence',
#  'support',
#  'surface',
#  'surge',
#  'survive',
#  'sustenance',
#  'tears',
#  'tectonic',
#  'tectonics',
#  'temblor',
#  'tephra',
#  'terremoto',
#  'tilt',
#  'transport',
#  'trembler',
#  'tremor',
#  'tuff',
#  'uneasy',
#  'uptight',
#  'vacate',
#  'vent',
#  'vents',
#  'vog',
#  'volcanic',
#  'volcano',
#  'volcanowatch',
#  'vulcan',
#  'vulcanian',
#  'vulcanoes',
#  'wasted',
#  'water',
#  'waves',
#  'withdraw'}

# %%
def find_emojis(lista):
    allchars = [str for str in lista.replace(" ","")]
    return [c for c in allchars if c in emoji.UNICODE_EMOJI] 

def normalize_text():
    
    #Cria uma dataSerie para ser adicionado ao dataFrame
    data['interest'] = False
    
    for index, line in enumerate(data['text']):
        TOKENS = remove_stopwords(line)
        data.at[index, 'text'] = " ".join(TOKENS)
        for token in TOKENS:
            if token in words:
                data.at[index, 'interest'] =  True
normalize_text()

# %%
data
# Out:
#             date        id_str        user_name  \
# 0     2018-05-09  2.992176e+08             0wwl
# 1     2018-05-03  1.291239e+09         1fsmith1
# 2     2018-05-08  1.209477e+08       1hawaiiboy
# 3     2018-04-30  1.209477e+08       1hawaiiboy
# 4     2018-05-02  1.209477e+08       1hawaiiboy
# 5     2018-05-08  1.534514e+09     24k_purelife
# 6     2018-05-05  1.534514e+09     24k_purelife
# 7     2018-05-01  1.599495e+09  2boldlygotravel
# 8     2018-05-08  2.155222e+07          3dueces
# 9     2018-04-30  3.891496e+08     3rdGalaxiArt
# 10    2018-05-06  1.720077e+09         808Plate
# 11    2018-05-01  4.654663e+08             995x
# 12    2018-04-30  4.654663e+08             995x
# 13    2018-05-08  3.343737e+07          AKLMaui
# 14    2018-04-30  3.343737e+07          AKLMaui
# 15    2018-05-06  3.343737e+07          AKLMaui
# 16    2018-05-07  3.343737e+07          AKLMaui
# 17    2018-05-08  3.343737e+07          AKLMaui
# 18    2018-05-01  1.197860e+08         AdamBuzz
# 19    2018-05-01  4.001255e+07      AdrianNBCLA
# 20    2018-05-08  4.001255e+07      AdrianNBCLA
# 21    2018-05-04  4.001255e+07      AdrianNBCLA
# 22    2018-05-07  4.001255e+07      AdrianNBCLA
# 23    2018-05-04  2.058055e+08     AdventurousZ
# 24    2018-04-30  2.650744e+09   AhlgrenJoachim
# 25    2018-05-06  1.575202e+09     AirHawaiiNet
# 26    2018-05-05  1.947484e+09      AlainaFuata
# 27    2018-05-03  5.032486e+07       AlexVNolan
# 28    2018-05-04  5.032486e+07       AlexVNolan
# 29    2018-05-06  5.032486e+07       AlexVNolan
# ...          ...           ...              ...
# 1506  2018-05-02  1.215502e+09        ubchillin
# 1507  2018-05-02  1.215502e+09        ubchillin
# 1508  2018-05-03  1.215502e+09        ubchillin
# 1509  2018-05-04  1.215502e+09        ubchillin
# 1510  2018-05-02  2.227127e+07         usdivers
# 1511  2018-04-30  3.910727e+07          verorox
# 1512  2018-05-24  4.144086e+07    viliutahhomes
# 1513  2018-05-09  2.402779e+08   vinodivasworld
# 1514  2018-05-09  2.402779e+08   vinodivasworld
# 1515  2018-05-07  9.694288e+17  visionary_coach
# 1516  2018-05-09  3.229828e+08    vlohvitstyler
# 1517  2018-05-09  3.229828e+08    vlohvitstyler
# 1518  2018-05-09  3.229828e+08    vlohvitstyler
# 1519  2018-05-06  1.224490e+09      wafiqrelaxx
# 1520  2018-05-04  1.074571e+08       weststream
# 1521  2018-05-06  1.127542e+07      whistlerdev
# 1522  2018-05-05  1.127542e+07      whistlerdev
# 1523  2018-05-07  1.127542e+07      whistlerdev
# 1524  2018-05-01  2.300007e+07     windrider808
# 1525  2018-05-01  7.708409e+17     woollybeanie
# 1526  2018-05-20  8.494682e+17   worldfrontpage
# 1527  2018-05-07  3.088387e+07            wubbi
# 1528  2018-05-02  3.088387e+07            wubbi
# 1529  2018-05-09  5.447417e+07   x3cinderella48
# 1530  2018-05-02  5.447417e+07   x3cinderella48
# 1531  2018-05-05  5.447417e+07   x3cinderella48
# 1532  2018-05-06  4.125238e+07        xtina1780
# 1533  2018-05-01  5.371431e+08    yuhino_51001F
# 1534  2018-05-04  2.640771e+08      zishin32555
# 724          NaN           NaN              NaN
#
#                                                    text      time   latitude  \
# 0                     island living 🏝 🥥 🌺 kapalua hawai  03:44:09  20.996700
# 1518                  lei making ladies kaanapali hawai  11:24:04  19.473500
# 1519                                         laptop cas  04:18:00  19.641880
# 1520  earthquakes amp volcanoes pair well sauvignon ...  04:38:19  20.934800
# 1521                                       staring beac  22:17:08  19.963531
# 1522      first time flying alaska airlines first class  01:34:12  19.828317
# 1523         swear traveling activates dna pololū valle  23:35:57  19.792401
# 1524  hawaii tribune heraldhilo hawaii usasunday may...  08:57:13  20.881017
# 1525              mauna loa letting steam hawaii island  18:37:01  20.203600
# 1526                     earthquake earthquake oh kalan  17:30:20  19.707243
# 1527   micah ’ last gymagery graduates pre school thank  00:40:02  19.566667
# 1528  lei day may day may day lei day happymayday da...  23:01:30  19.410160
# 1529     happiest boy ’ day one boy never break mommy ’  07:58:32  20.885263
# 1530                         always try sit close ocean  05:56:04  20.692604
# 1531  昨日のハワイ写真のつづき 。 キラウエア火山国立公園でのレインボー 。 上の方は大雨 。 下...  15:12:23  20.913120
# 1532  【 海外地震情報 】 年月日 時分頃 、 北東太平洋 （ ハワイ諸島 ） 北緯 度 西経 度...  21:50:25  20.687627
# 1533  【 海外地震情報 】 年月日 時分頃 、 北東太平洋 （ ハワイ諸島 ） 北緯 度 西経 度...  13:17:04  19.399230
# 1534             hawaii great memories bad sunburn lots  23:36:54  19.400000
# 724           life gucci basic gucci guccilover sobasic       NaN        NaN
#
#        longitude  interest
# 0    -156.653000      True
# 1    -155.989839      True
# 2    -156.005000      True
# 3    -155.879406     False
# 4    -155.884330     False
# 5    -156.692440     False
# 6    -156.675000     False
# 7    -156.477408     False
# 8    -156.441752     False
# 9    -155.993150     False
# 10   -156.440300      True
# 11   -156.679000     False
# 12   -155.646712     False
# 13   -156.319407     False
# 14   -156.319407     False
# 15   -156.319407     False
# 16   -156.319407     False
# 17   -156.319407     False
# 18   -155.991320      True
# 19   -156.445000      True
# 20   -156.442768     False
# 21   -156.441055     False
# 22   -156.445000     False
# 23   -156.675000     False
# 24   -156.692440      True
# 25   -155.985540      True
# 26   -154.920000      True
# 27   -156.443887     False
# 28   -156.668731     False
# 29   -156.668731     False
# ...          ...       ...
# 1506 -155.910770      True
# 1507 -155.965000      True
# 1508 -155.931141     False
# 1509 -155.287000     False
# 1510 -156.430556     False
# 1511 -155.885795      True
# 1512 -156.041082     False
# 1513 -156.438890      True
# 1514 -156.507211     False
# 1515 -155.871263     False
# 1516 -154.920000      True
# 1517 -155.205000     False
# 1518 -154.920000      True
# 1519 -155.993150     False
# 1520 -156.679000     False
# 1521 -155.854733     False
# 1522 -155.992547     False
# 1523 -156.027489     False
# 1524 -156.454493      True
# 1525 -155.734000      True
# 1526 -155.081635      True
# 1527 -155.500000     False
# 1528 -154.913839     False
# 1529 -156.464937     False
# 1530 -156.442535     False
# 1531 -156.692440     False
# 1532 -156.443134     False
# 1533 -155.287000     False
# 1534 -155.000000      True
# 724          NaN     False
#
# [1535 rows x 8 columns]

# %%
data[data['interest'] == True]
