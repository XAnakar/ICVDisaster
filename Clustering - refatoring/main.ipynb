# %%
import pandas as pd
data = pd.read_csv("names.csv")
data.head()
# Out:
#           id          nome                       data/hora   latitude  \
# 0   42138551        mlkmus  Wed May 09 14:56:49 +0000 2018  20.985902
# 1  362523555   QuakesToday  Wed May 09 14:45:10 +0000 2018  19.300000
# 2  362523555   QuakesToday  Wed May 09 14:20:04 +0000 2018  19.392000
# 3   79450692  LaSardineCan  Wed May 09 14:16:38 +0000 2018  19.429185
# 4  221399915  KelseyMarier  Wed May 09 14:11:12 +0000 2018  20.987778
#
#     longitude
# 0 -156.668731
# 1 -155.248000
# 2 -154.928000
# 3 -155.257573
# 4 -156.667778

# %%
print(data)
# Out:
#                       id             nome                       data/hora  \
# 0               42138551           mlkmus  Wed May 09 14:56:49 +0000 2018
# 1              362523555      QuakesToday  Wed May 09 14:45:10 +0000 2018
# 2              362523555      QuakesToday  Wed May 09 14:20:04 +0000 2018
# 3               79450692     LaSardineCan  Wed May 09 14:16:38 +0000 2018
# 4              221399915     KelseyMarier  Wed May 09 14:11:12 +0000 2018
# 5              362523555      QuakesToday  Wed May 09 14:05:05 +0000 2018
# 6               43163920         GevaNeva  Wed May 09 14:00:11 +0000 2018
# 7              362523555      QuakesToday  Wed May 09 13:55:06 +0000 2018
# 8               17199767        EdTecHakk  Wed May 09 13:15:54 +0000 2018
# 9              362523555      QuakesToday  Wed May 09 13:10:04 +0000 2018
# 10             362523555      QuakesToday  Wed May 09 13:00:05 +0000 2018
# 11             362523555      QuakesToday  Wed May 09 12:50:06 +0000 2018
# ...
